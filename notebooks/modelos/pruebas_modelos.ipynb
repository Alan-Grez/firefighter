# %% [markdown]
# # Pruebas con modelos
#
# Este notebook es una plantilla para probar enfoques de modelado con los datos del repositorio.
# Define una columna objetivo y agrega las transformaciones necesarias según el caso.

# %%
from pathlib import Path
import pandas as pd

data_path = Path("../../data_2020/data_2020.csv")
df = pd.read_csv(data_path)
df.head()

# %%
# Revisa las columnas disponibles antes de definir un objetivo.
df.columns

# %%
# TODO: reemplaza None por el nombre de la columna objetivo.
target_column = None

if target_column is None:
    print("Define target_column con el nombre de la variable a modelar.")
else:
    target_summary = df[target_column].value_counts().head(10)
    target_summary
